# %% [markdown]
# # M1-INF4 – Python Workshop for Data Analysis
# ## Session 1 – Python & NumPy Essentials
#
# **Master 1 IBI / SBI — Paris 1 Panthéon-Sorbonne**
#
#
# ***
# ##### **Groupe : Léo Ajas, André Margaryan, Alexis Hummel, Manil Benmoussa**
# ---

# %% [markdown]
# ### Learning objectives
#
# By the end of this session, students will be able to:
#
# - Use a Jupyter Notebook in VS Code
# - Refresh essential Python programming concepts for data analysis
# - Reuse simple Python functions in a short business problem
# - Manipulate numerical data with NumPy
# - Use indexing, slicing, and vectorized operations
# - Compute basic descriptive statistics
# - Load and inspect a real dataset with pandas
#
# ### Today's workflow
#
# Python refresher → NumPy (main new content) → Real-world data

# %% [markdown]
# ## 0. Environment Setup
#
# During this course, we will use **Python** and **Jupyter Notebooks** inside **Visual Studio Code (VS Code)**.
#
# The objective of this first section is to make sure that everyone has the same working environment.
#
# ### Software used in this course
#
# We will use:
#
# - Python 3.12 or later
# - Visual Studio Code
# - Jupyter Notebooks
# - NumPy
# - pandas
# - Matplotlib
#
# ---
#
# ### 0.1 Install Python
#
# Download and install Python from the official Python website:
#
# **https://www.python.org/downloads/**
#
# Python **3.12 or later** is recommended.
#
# #### Windows users
#
# During installation, make sure to select:
#
# > **Add Python to PATH**
#
# #### Check your installation
#
# Open a terminal and run:
#
# ```bash
# python --version
# ```
#
# If this command does not work on macOS or Linux, try:
#
# ```bash
# python3 --version
# ```
#
# You should see something similar to:
#
# ```text
# Python 3.12.x
# ```
#
# ---
#
# ### 0.2 Install Visual Studio Code
#
# Download and install Visual Studio Code:
#
# **https://code.visualstudio.com/**
#
# We will use VS Code throughout the course to:
#
# - edit Python code;
# - run Jupyter Notebooks;
# - manage project files;
# - use the integrated terminal.
#
# ---
#
# ### 0.3 Install the VS Code extensions
#
# Open VS Code.
#
# Click the **Extensions** icon in the left sidebar.
#
# Search for and install the following Microsoft extensions:
#
# 1. **Python**
# 2. **Jupyter**
#
# These extensions allow VS Code to execute Python code and Jupyter Notebooks.
#
# ---
#
# ### 0.4 Open the course folder
#
# The course has the following structure (`<course-folder>` stands for the folder supplied for your course):
#
# ```text
# <course-folder>/
# │
# ├── data/
# │   ├── homelessness.csv
# │   ├── sales_subset.csv
# │   └── temperatures.csv
# │
# ├── notebooks/
# │   ├── 01-Python-NumPy.ipynb
# │   ├── 02-Pandas-Manipulation.ipynb
# │   ├── 03-Data-Cleaning.ipynb
# │   ├── 04-EDA-Visualization.ipynb
# │   └── 05-Data-Integration-Case-Study.ipynb
# │
# └── requirements.txt
# ```
#
# In VS Code, select:
#
# **File → Open Folder**
#
# and open the folder:
#
# ```text
# <course-folder>
# ```
#
# ⚠️ Open the **whole course folder**, not only the `.ipynb` file.
#
# ---
#
# ### 0.5 Open the VS Code terminal
#
# In VS Code, select:
#
# **Terminal → New Terminal**
#
# A terminal will appear at the bottom of the window.
#
# Check that you are inside the course directory.
#
# Your terminal should end with something similar to:
#
# ```text
# <course-folder>
# ```
#
# ---
#
# ### 0.6 Create a Python virtual environment
#
# A **virtual environment** creates an isolated Python environment for the project.
#
# This helps ensure that everyone uses the required Python packages without interfering with other Python projects.
#
# #### Windows
#
# ```powershell
# python -m venv .venv
# ```
#
# #### macOS / Linux
#
# ```bash
# python3 -m venv .venv
# ```
#
# A new directory named `.venv` will be created.
#
# You only need to create this environment **once**.
#
# ---
#
# ### 0.7 Activate the virtual environment
#
# #### Windows – PowerShell
#
# ```powershell
# .venv\Scripts\Activate.ps1
# ```
#
# #### Windows – Command Prompt
#
# ```cmd
# .venv\Scripts\activate
# ```
#
# #### macOS / Linux
#
# ```bash
# source .venv/bin/activate
# ```
#
# When the environment is activated, you should normally see:
#
# ```text
# (.venv)
# ```
#
# at the beginning of your terminal prompt.
#
# ---
#
# ### 0.8 Install the Python packages
#
# With the virtual environment activated, install the packages required for the course:
#
# ```bash
# python -m pip install -r requirements.txt
# ```
#
# The `requirements.txt` file contains the Python libraries used during the course.
#
# For this course, the main libraries are:
#
# - `numpy` — numerical computing;
# - `pandas` — data manipulation;
# - `matplotlib` — data visualization;
# - `jupyter` / `ipykernel` — Jupyter Notebook support.
#
# ---
#
# ### 0.9 Open the first notebook
#
# In the VS Code Explorer, open:
#
# ```text
# notebooks/01-Python-NumPy.ipynb
# ```
#
# A Jupyter Notebook is composed of **cells**.
#
# Two important cell types are:
#
# - **Markdown cells** — explanations, documentation, instructions;
# - **Code cells** — executable Python code.
#
# You can execute a code cell using the ▶ button or:
#
# ```text
# Shift + Enter
# ```
#
# ---
#
# ### 0.10 Select the Python kernel
#
# At the top-right of the notebook, click:
#
# **Select Kernel**
#
# Choose the Python environment corresponding to:
#
# ```text
# .venv
# ```
#
# The selected Python version should be the one associated with the virtual environment created for this course.
#
# ---
#
# ### 0.11 Test your environment
#
# Run the following cell:
#
# ```python
# print("Welcome to M1-INF4!")
# print("Python is ready.")
# ```
#
# Expected output:
#
# ```text
# Welcome to M1-INF4!
# Python is ready.
# ```
#
# Now test the main libraries:
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# print("NumPy version:", np.__version__)
# print("pandas version:", pd.__version__)
# print("Environment ready!")
# ```
#
# If this cell runs without an error, your environment is ready for the course.
#
# ---
#
# ### 0.12 Troubleshooting
#
# #### `python` command not found
#
# Try:
#
# ```bash
# python3 --version
# ```
#
# If Python is still not recognized, check that Python is correctly installed.
#
# ---
#
# #### `ModuleNotFoundError`
#
# Example:
#
# ```text
# ModuleNotFoundError: No module named 'pandas'
# ```
#
# First check that your virtual environment is activated.
#
# Then run:
#
# ```bash
# python -m pip install -r requirements.txt
# ```
#
# Finally, check that the `.venv` kernel is selected in VS Code.
#
# ---
#
# #### The notebook uses the wrong Python version
#
# Click **Select Kernel** in the top-right corner of the notebook and select the `.venv` environment.
#
# If necessary, restart the notebook kernel.
#
# ---
#
# ### 💡 Key idea
#
# Our working environment is:
#
# ```text
# VS Code
#    ↓
# Jupyter Notebook
#    ↓
# Python virtual environment (.venv)
#    ↓
# NumPy / pandas / Matplotlib
#    ↓
# Data
# ```
#
# Once the environment is configured, we can focus on what really matters:
#
# > **using Python to explore, manipulate, analyze, and understand data.**
#
# ---
#
# If your environment is already installed, check the kernel and imports. Keep the full instructions above as a reference.
#
# The objectives and workflow are listed at the start of this notebook.

# %% [markdown]
# ## 1. Getting started with Jupyter Notebooks
#
# A Jupyter Notebook combines:
#
# - **Markdown cells** for explanations and documentation
# - **Code cells** for executable Python code
# - **Outputs** displayed directly below the code
#
# Throughout this course, we will use notebooks to explore, manipulate, visualize, and interpret data.

# %%
print("Welcome to M1-INF4!")
print("Python is ready.")
# Out:
# Welcome to M1-INF4!
# Python is ready.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy version:", np.__version__)
print("pandas version:", pd.__version__)
print("Environment ready!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# NumPy version: 2.5.3
# pandas version: 3.0.6
# Environment ready!

# %% [markdown]
# ## 2. Python Refresher for Data Analysis
#
# Before working with data, let's review a few Python concepts that we will use throughout the course:
#
# - variables and basic data types
# - lists and dictionaries
# - indexing and slicing
# - conditions and loops
# - functions
#
# This section is a quick refresher rather than a complete introduction to Python.
# You have already studied algorithmic concepts and object-oriented programming; Python syntax may be less familiar. We will not study programming from scratch. Read familiar examples independently; use the explanations when needed.
#
# Additional Python exercises and their solutions are available in **Appendix A (extra practice)**.

# %%
# Basic Python objects

course = "Data Analysis with Python"
students = 28
duration = 3
is_master_course = True

print(course)
print(type(course))
print(type(students))
print(type(duration))
print(type(is_master_course))
# Out:
# Data Analysis with Python
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ### 2.1 Lists and indexing
#
# A Python list stores an ordered collection of values.
#
# Python uses **zero-based indexing**: the first element has index `0`.

# %%
scores = [12, 15, 9, 18, 14]

print("All scores:", scores)
print("First score:", scores[0])
print("Last score:", scores[-1])
print("First three scores:", scores[:3])
# Out:
# All scores: [12, 15, 9, 18, 14]
# First score: 12
# Last score: 14
# First three scores: [12, 15, 9]

# %% [markdown]
# ### 2.2 Dictionaries
#
# A Python dictionary stores data as **key-value pairs**.
#
# Dictionaries are useful when data have meaningful labels rather than numerical positions.

# %%
student = {
    "name": "Alice",
    "program": "SBI",
    "grade": 15.5,
    "passed": True
}

print(student)
print("Name:", student["name"])
print("Grade:", student["grade"])
# Out:
# {'name': 'Alice', 'program': 'SBI', 'grade': 15.5, 'passed': True}
# Name: Alice
# Grade: 15.5

# %%
student["grade"] = 16
student["year"] = "M1"

print(student)
# Out:
# {'name': 'Alice', 'program': 'SBI', 'grade': 16, 'passed': True, 'year': 'M1'}

# %% [markdown]
# ### 2.3 Conditions and loops
#
# Conditions allow a program to make decisions.
#
# Loops allow us to repeat an operation over several values.

# %%
scores = [12, 15, 9, 18, 14]

for score in scores:
    if score >= 10:
        print(score, "→ Pass")
    else:
        print(score, "→ Fail")
# Out:
# 12 → Pass
# 15 → Pass
# 9 → Fail
# 18 → Pass
# 14 → Pass

# %% [markdown]
# ### 2.4 Functions
#
# A function groups reusable instructions.
#
# Functions help us avoid repeating code and make data-processing workflows easier to understand.

# %%
def classify_score(score):
    if score >= 10:
        return "Pass"
    else:
        return "Fail"


print(classify_score(15))
print(classify_score(8))
# Out:
# Pass
# Fail

# %% [markdown]
# ### ✏️ Mini-challenge — A first sales report
#
# You are a junior data analyst for an e-commerce company. Your manager gives you the sales amounts (in euros) for six completed orders. Prepare a short report using **plain Python**, before moving to NumPy.
#
# **Work in pairs:** agree on an approach, write your code, then compare and explain your results. Use the refresher examples if needed.
#
# 1. Display the number of orders, total sales and average sales per order.
# 2. Write `classify_sales(value)`: return `"High"` for a value greater than or equal to 150, and `"Standard"` otherwise. Apply it to each amount.
# 3. Use a loop and a condition to build a list of the amounts classified as `"High"`.
# 4. Store the number of orders, total and mean in a dictionary called `report`, using the keys `"orders"`, `"total"`, `"mean"`. Print it and explain one result to your partner.
#
# **Self-check:** 6 orders; total €770; average approximately €128.33; high amounts `[180, 160]`. Interpret the average as sales per completed order, not monthly sales or sales per customer.
#
# Do not open the solution until you have tried. The purpose is to diagnose Python fluency, not introduce new syntax.

# %%
sales = [120, 95, 140, 180, 75, 160]

# 1. Number of orders, total and mean
nbr_orders = len(sales)

total=0
for sale in sales:
    total = total + sale

# on peut possiblement utiliser sum() aussi
print(total)

mean = total / nbr_orders

print(round(mean,2)) # affichage arrondi


# 2. Define classify_sales(value), then apply it to each amount

def classify_sales(value):
    if value >= 150:
        return "High"
    return "Standard"

for sale in sales:
    print(classify_sales(sale)) # application de la fonction sur les sales

# 3. Build the list of high amounts using a loop and a condition

list_high = []
for sale in sales:
    if classify_sales(sale)=="High":
        list_high.append(sale) # on ajoute à la nouvelle liste
        
print(list_high)
        

# 4. Build and display report

# construction du dico en utilisant les variables precedentes
report = {
    "orders": nbr_orders,
    "total": total,
    "mean": mean
}

print(report)
# Out:
# 770
# 128.33
# Standard
# Standard
# Standard
# High
# Standard
# High
# [180, 160]
# {'orders': 6, 'total': 770, 'mean': 128.33333333333334}

# %% [markdown]
# <details>
# <summary>Solution — open after attempting the challenge</summary>
#
# ```python
# sales = [120, 95, 140, 180, 75, 160]
# number_of_orders = len(sales)
# total_sales = sum(sales)
# mean_sales = total_sales / number_of_orders
# print(number_of_orders, total_sales, mean_sales)
#
# def classify_sales(value):
#     if value >= 150:
#         return "High"
#     else:
#         return "Standard"
#
# high_sales = []
# for value in sales:
#     print(value, "→", classify_sales(value))
#     if value >= 150:
#         high_sales.append(value)
#
# report = {"orders": number_of_orders, "total": total_sales, "mean": mean_sales}
# print(high_sales)
# print(report)
# ```
#
# The average describes these six orders; it does not explain why their values differ. The list is non-empty, so division by the number of orders is valid here.
#
# </details>

# %% [markdown]
# ## 3. From Python Lists to NumPy Arrays
#
# Python lists are convenient, but data analysis often requires performing numerical operations on many values.
#
# **NumPy** (Numerical Python) provides efficient multidimensional arrays and numerical operations.
#
# Let's compare a Python list with a NumPy array.
# **Main new content:** NumPy arrays, indexing, filtering, vectorization and descriptive statistics.
#
# The sales examples describe small fictional business datasets. Their values and observation units are stated separately; they are not all the same dataset.

# %%
import numpy as np

sales_list = [120, 135, 150, 165]

sales_array = np.array(sales_list)

print("Python list:", sales_list)
print("NumPy array:", sales_array)
# Out:
# Python list: [120, 135, 150, 165]
# NumPy array: [120 135 150 165]

# %%
# What happens if we multiply by 2?

print("Python list:")
print(sales_list * 2)

print("\nNumPy array:")
print(sales_array * 2)
# Out:
# Python list:
# [120, 135, 150, 165, 120, 135, 150, 165]
#
# NumPy array:
# [240 270 300 330]

# %% [markdown]
# ### 3.1 Exploring NumPy arrays
#
# A NumPy array has several useful properties:
#
# - `shape` — dimensions of the array
# - `size` — total number of elements
# - `dtype` — data type of the elements
# - `ndim` — number of dimensions

# %%
sales = np.array([120, 135, 128, 150, 165, 172])

print("Array:", sales)
print("Shape:", sales.shape)
print("Size:", sales.size)
print("Data type:", sales.dtype)
print("Number of dimensions:", sales.ndim)
# Out:
# Array: [120 135 128 150 165 172]
# Shape: (6,)
# Size: 6
# Data type: int64
# Number of dimensions: 1

# %% [markdown]
# ### 3.2 Indexing and slicing
#
# NumPy arrays use the same basic indexing principles as Python lists.
#
# We can access individual observations or select subsets of an array.

# %%
sales = np.array([120, 135, 128, 150, 165, 172])

print("First value:", sales[0])
print("Last value:", sales[-1])
print("First three values:", sales[:3])
print("Values from index 2 to 4:", sales[2:5])
# Out:
# First value: 120
# Last value: 172
# First three values: [120 135 128]
# Values from index 2 to 4: [128 150 165]

# %% [markdown]
# ### 3.3 Filtering data
#
# NumPy can select observations that satisfy a condition.
#
# The expression below creates a Boolean array containing `True` or `False` for each observation.

# %%
sales >= 150
# Out:
# array([False, False, False,  True,  True,  True])

# %%
# Use the Boolean mask to select the matching observations
print("Sales >= 150:", sales[sales >= 150])
# Out:
# Sales >= 150: [150 165 172]

# %% [markdown]
# ### 3.4 Vectorized operations
#
# NumPy allows us to perform an operation on an entire array without writing an explicit loop.
#
# This is called **vectorization**.

# %%
sales = np.array([120, 135, 128, 150, 165, 172])

# Apply a 10% increase
sales_after_increase = sales * 1.10

print("Original sales:", sales)
print("After 10% increase:", sales_after_increase)
# Out:
# Original sales: [120 135 128 150 165 172]
# After 10% increase: [132.  148.5 140.8 165.  181.5 189.2]

# %%
difference = sales_after_increase - sales

print("Increase:", difference)
# Out:
# Increase: [12.  13.5 12.8 15.  16.5 17.2]

# %% [markdown]
# ### 3.5 Descriptive statistics
#
# NumPy provides functions for computing common summary statistics.
#
# These statistics help us obtain a first understanding of a dataset.

# %%
sales = np.array([120, 135, 128, 150, 165, 172])

print("Mean:", np.mean(sales))
print("Median:", np.median(sales))
print("Minimum:", np.min(sales))
print("Maximum:", np.max(sales))
print("Standard deviation:", np.std(sales))
# Out:
# Mean: 145.0
# Median: 142.5
# Minimum: 120
# Maximum: 172
# Standard deviation: 19.008769905844336

# %% [markdown]
# **“Why might the median sometimes be more informative than the mean?”**

# %% [markdown]
# ### ✏️ Your turn — Monthly revenue analysis
#
# A company recorded the following monthly revenues (in thousands of euros):
#
# ```python
# revenue = np.array([42, 48, 51, 39, 55, 62, 58, 70, 65, 74, 69, 80])
# ```
#
# Try the six tasks before opening the solution.

# %% [markdown]
# 1. Display the number of observations.
# 2. Compute the mean revenue.
# 3. Find the minimum and maximum revenue.
# 4. Select all months with revenue greater than or equal to 60.
# 5. Apply a hypothetical 5% increase to all revenues.
# 6. Count how many months have revenue greater than or equal to 60.

# %%
revenue = np.array([42, 48, 51, 39, 55, 62, 58, 70, 65, 74, 69, 80])

print("number of obs :", revenue.size)

print("mean revenue : ", revenue.mean()) # ou np.mean(revenue) mais la liste est deja une array numpy

print("max revenue : ", revenue.max())

print("min revenue : ", revenue.min())

print("all months with revenue greater than or equal to 60", revenue[revenue >= 60])

revenue_increased = revenue * 1.05
print(revenue_increased)

print("nbr of months with revenue greater than or equal to 60 : ", np.sum(revenue >= 60))
# Out:
# number of obs : 12
# mean revenue :  59.416666666666664
# max revenue :  80
# min revenue :  39
# all months with revenue greater than or equal to 60 [62 70 65 74 69 80]
# [44.1  50.4  53.55 40.95 57.75 65.1  60.9  73.5  68.25 77.7  72.45 84.  ]
# nbr of months with revenue greater than or equal to 60 :  6

# %%
# Solution

print("Number of observations:", revenue.size)
print("Mean:", np.mean(revenue))
print("Minimum:", np.min(revenue))
print("Maximum:", np.max(revenue))

high_revenue = revenue[revenue >= 60]
print("Revenue >= 60:", high_revenue)

revenue_after_increase = revenue * 1.05
print("After 5% increase:", revenue_after_increase)

print("Number of months >= 60:", np.sum(revenue >= 60))
# Out:
# Number of observations: 12
# Mean: 59.416666666666664
# Minimum: 39
# Maximum: 80
# Revenue >= 60: [62 70 65 74 69 80]
# After 5% increase: [44.1  50.4  53.55 40.95 57.75 65.1  60.9  73.5  68.25 77.7  72.45 84.  ]
# Number of months >= 60: 6

# %% [markdown]
# ### 3.6 Two-dimensional arrays — OPTIONAL / IF TIME ALLOWS
#
# NumPy can also represent data in multiple dimensions.
#
# A two-dimensional array can be viewed as a table composed of rows and columns.
# This optional subsection is not a prerequisite for the pandas introduction. You can continue directly to section 4.

# %%
data = np.array([
    [120, 10],
    [135, 12],
    [150, 15],
    [165, 14]
])

print(data)
print("Shape:", data.shape)

# %%
# First row
print(data[0])

# First column
print(data[:, 0])

# Second column
print(data[:, 1])

# %% [markdown]
# ## 4. From NumPy to pandas: Working with Real Data
#
# So far, we have manipulated data stored in Python lists and NumPy arrays.
#
# In real data-analysis projects, data are often stored in tabular files such as CSV files.
#
# The **pandas** library provides the `DataFrame`, a convenient structure for working with rows and columns.
#
# Let's explore our first real dataset.
# Use `homelessness.csv` for the guided exploration. The second CSV exercise provides optional further practice.
#
# Keep this notebook in the course `notebooks/` directory. The relative paths require a working directory of `notebooks/` and the course CSV files in `../data/`. The real CSV files are not embedded in this notebook.

# %%
import pandas as pd

homelessness = pd.read_csv("../data/homelessness.csv")

# %% [markdown]
# ### 4.1 First look at the dataset
#
# Before analyzing a new dataset, we should first understand its structure.
#
# Some useful questions are:
#
# - What does the dataset look like?
# - How many rows and columns are there?
# - What are the column names?
# - What types of data do the columns contain?

# %%
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %% [markdown]
# **What do you think one row represents? What variables can you identify?**

# %%
homelessness.shape
# Out:
# (51, 6)

# %%
homelessness.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='str')

# %%
homelessness.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     str
#  2   state           51 non-null     str
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), str(2)
# memory usage: 2.5 KB

# %% [markdown]
# ### 💡 Takeaway
#
# When opening a new dataset, a useful first workflow is:
#
# ```python
# df.head()
# df.shape
# df.columns
# df.info()
#
# ```
#
# These commands help us understand the content, dimensions, variables, and data types before performing any analysis.

# %% [markdown]
# ### ✏️ Your turn — Explore a second dataset (OPTIONAL / FOLLOW-UP)
#
# Now explore the `sales_subset.csv` dataset.
#
# 1. Load the dataset using `pd.read_csv()`.
# 2. Display its first rows.
# 3. Determine its number of rows and columns.
# 4. Display the column names.
# 5. Inspect its data types using `info()`.
#
# **Question:** Which columns seem numerical? Which columns seem categorical?
# Use the same exploration workflow on this second dataset to consolidate your understanding.

# %%
# Load the dataset
sales = pd.read_csv("../data/sales_subset.csv")

# Explore the dataset
sales.head()
sales.shape
sales.columns
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10774 non-null  int64
#  1   store                 10774 non-null  int64
#  2   type                  10774 non-null  str
#  3   department            10774 non-null  int64
#  4   date                  10774 non-null  str
#  5   weekly_sales          10774 non-null  float64
#  6   is_holiday            10774 non-null  bool
#  7   temperature_c         10774 non-null  float64
#  8   fuel_price_usd_per_l  10774 non-null  float64
#  9   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(3), str(2)
# memory usage: 768.2 KB

# %%
# Solution

sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales.shape

# %%
sales.columns

# %%
sales.info()

# %% [markdown]
# ## 5. Session 1 — Key Takeaways
#
# Today we moved from a Python refresher to real-world data analysis.
#
# We reviewed:
#
# - Python variables and data structures
# - Lists, dictionaries, conditions, loops, and functions
# - NumPy arrays
# - Indexing and filtering
# - Vectorized numerical operations
# - Basic descriptive statistics
# - Loading a CSV file with pandas
# - First steps for exploring a DataFrame
#
# ### Next session
#
# In the next session, we will focus on **data manipulation with pandas**:
#
# **select → filter → sort → transform → aggregate**
# **Check your understanding:** explain how list multiplication differs from array multiplication, distinguish a Boolean mask from the selected values, and name the first commands you would use to inspect a CSV.

# %% [markdown]
# ## Appendix A — Python exercises (extra practice)
#
# Use these exercises and their solutions for additional practice or individual revision.

# %% [markdown]
# ### ✏️ Your turn
#
# Given the following list of monthly sales:
#
# ```python
# sales = [120, 135, 128, 150, 165, 172]
# ```

# %% [markdown]
# 1. Display the first value.
# 2. Display the last value.
# 3. Display the first three values.
# 4. Compute the number of observations using len().
# 5. Compute the total sales using sum().

# %%
sales = [120, 135, 128, 150, 165, 172]

print("first value:", sales[0])
print("last value :", sales[-1])
print("first three values:", sales[:3])
print("nbr of obs:", len(sales))
print("total :", sum(sales))
# Out:
# first value: 120
# last value : 172
# first three values: [120, 135, 128]
# nbr of obs: 6
# total : 870

# %%
# Solution

print("First:", sales[0])
print("Last:", sales[-1])
print("First three:", sales[:3])
print("Number of observations:", len(sales))
print("Total:", sum(sales))

# %% [markdown]
# ### ✏️ Your turn
#
# Consider the following sales data:
#
# ```python
# sales = [120, 95, 140, 180, 75, 160]
#
# ```
#
# Write a function called classify_sales() that:
# - takes one sales value as input;
# - returns "High" if the value is greater than or equal to 150;
# - returns "Standard" otherwise.
# Then apply the function to every value in sales.

# %%
sales = [120, 95, 140, 180, 75, 160]

# la fonction
def classify_sales(value):
    if value >= 150:
        return "High"
    return "Standard"

# on applique sur chacune des valeurs
for value in sales:
    print(value, " : ", classify_sales(value))

# Apply it to every sales value
# Out:
# 120  :  Standard
# 95  :  Standard
# 140  :  Standard
# 180  :  High
# 75  :  Standard
# 160  :  High

# %%
# Solution

def classify_sales(value):
    if value >= 150:
        return "High"
    else:
        return "Standard"


for value in sales:
    print(value, "→", classify_sales(value))
